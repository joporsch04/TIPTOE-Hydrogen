# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
pd.set_option('display.float_format', lambda x: "%.2E" % x )
import glob
import tRecX_IO as io
sim = io.tRecX_sim
from scipy import constants

Inj_lam=850
Drive_lam=350
name=f'{Inj_lam}nm/{Drive_lam}_nm_Drive_lower_Int'
rex= sim(name)
factor=4
BOX=60//factor
rex.upper_trunk=BOX
rex.boundary_au=BOX
rex.eta_coeff=90//factor
rex.phi_coeff=1
rex.lower_trunc=np.asarray(BOX)-10
rex.cutEnergy=200//factor
rex.grid_spacing=10
rex.fixStep=0.01*factor
rex.store=0.1
rex.expecVal_inside=f'\'Occupation[0,1,2,3,4,5]\''
### injection ###
rex.injection_Intensity_Wcm2=1.25e14*0.6
rex.injection_wavelength_nm=Inj_lam
rex.injection_CEPhase='cos'
rex.injection_FWHM=np.asarray([1])
### drive ###
rex.drive_wavelength_nm=lamb=Drive_lam
rex.drive_Intensity_Wcm2=1e10*0.6
rex.drive_FWHM_OptCyc=0.8

rex.convergence_test_bool=False
rex.order=20
rex.Rn_coeff_outer=20
rex.R_density_Spectrum=256
rex.drive_polar_angle=0 
rex.calc()
rex.expecVals_outside='<1><1><GridWeight>, <1><Q><GridWeight*Q>, <cos(Q)><sqrt(1-Q*Q)><GridWeight*Q>, <sin(Q)><sqrt(1-Q*Q)><GridWeight*Q>'
#print(rex.end_sim, rex.N_drive, rex.N_injection)
rex.ecs_coeff=0.1
rex.N_drive=1*rex.N_drive
rex.csv_populate_self()
for file in glob.glob(name+f'/list.csv'):
    print("")
    io.tRecX_write_inp(file)
    io.row_wise_submit_local(file)
del rex
# Out:
# Nyquist condition not fullfilled.
#  minimum sampling points =  23.0 current sampling points: 21
# #injection field samples: 10  #drive samples outside this regime:  21
# delay Aray (every 5th elem) :  [-481.8  -292.79 -103.77  -51.89    0.     51.89  103.77  292.79  481.8 ]
#
#
#  -> tRecX (v 2.0) (C) 2015-2024 Armin Scrinzi (licenced under GPLv2) <-
#
#  Build: May 16 2024 10:37:10, git hash 658b04d, type "Parallel"
#
#
#
#  *** further output on /home/user/TIPTOE/850nm/350_nm_Drive_lower_Int//0/outf ***
#
#
#  ===  Date [06/26 13:07:27] Photoconductive Sampling -  ========================
#
#  !!! WARNING --- Axis:lower end OBSOLESCENT -- change name to "lowerEnd" --- WARNING !!!
#
#  !!! WARNING --- Axis:upper end OBSOLESCENT -- change name to "upperEnd" --- WARNING !!!
#
#  !!! WARNING --- Axis:lower end OBSOLESCENT -- change name to "lowerEnd" --- WARNING !!!
#
#                  !!! Limit=1 reached, no further warnings: Axis:lower end OBSOL... !!!
#
#  !!! WARNING --- Axis:upper end OBSOLESCENT -- change name to "upperEnd" --- WARNING !!!
#
#                  !!! Limit=1 reached, no further warnings: Axis:upper end OBSOL... !!!
#
#  !!! WARNING --- Absorption:upper OBSOLESCENT -- change name to "radius" --- WARNING !!!
#
#  !!! WARNING --- Absorption:upper OBSOLESCENT -- change name to "radius" --- WARNING !!!
#
#                  !!! Limit=1 reached, no further warnings: Absorption:upper OBS... !!!
#
#  Master host = mpq6p100 (4 processes)
#
#  *** OK inverse overlap: S Sinv, error=2.2e-16 ... Sinv S, error=2.2e-16 (Phi.Eta.Rn.Rn) ***
#
#
#  ===  DVR --- DISCRETIZATION  ==================================================
#
#                Name: Phi.Eta.Rn
#
#    Axis maxCoeff from       to order                basis      absorption: eta,inner
#      --   ------   --   ------   ---   ------------------   ------------------------
#     Phi        1    0    6.283     1               cosSin
#     Eta       22   -1        1    22   assocLegendre{Phi}
#      Rn       38    0 15|Infty    20 polynomial/polExp... ECS:(0.995,0.0998)[-15,15]
#  Full basis name(s): polynomial/polExp[0.5]
#          total size: 858
#
#            Surfaces: default (at complex scaling radius)
#
#
#  ===  OPERATORS  ===============================================================
#
#         Hamiltonian: 1/2<<Laplacian>>-<1><1><trunc[5,15]/Q>
#         Interaction: iLaserAz[t]<<D/DZ>>+iLaserAx[t]<<D/DX>>+iLaserAy[t]<<D/DY>>
#          HamInitial: H(t=Begin)
#
#  Expectation Values: Occupation[0,1,2,3,4,5]
#          Projection: default
#  --- potentials truncated by trunc[0,15] ---
#
#
#
#  ===  Laser  ===================================================================
#
#    polAxis Shape Intens(W/cm2) lambda(nm) photon(eV)  FWHM  begin    end phiCEO
#      -----   ---   -----------   --------   --------   ---   ----   ----   ----
#    [1 0 0]  cos8       7.5e+13        850      1.459 117.2   -315    315
#    [1 0 0]  cos8         6e+09        350      3.542 38.45 -585.1 -378.5  1.571
#
#  ponderomotive potential (eV): 5.06
#
#  *** Multi-color pulse, OptCyc is for 1st color, value=117.215 (au) ***
#       Initial state: atBegin for operator H(t=Begin)
#
#
#  ===  OUTPUT  ==================================================================
#           Directory: /home/user/TIPTOE/850nm/350_nm_Drive_lower_Int//0/
#
#  *** Description of input on file /home/user/tRecX/tRecX.doc ***
#
#
#
#  ===  End of Input - timing  ===================================================
#
#                      File: Name                          calls   cpu(total)   cpu/call [samp]
#                 run_trecx: all                               4       0.986       0.247
#                 run_trecx: setup                             3       0.464       0.155
#                mpiWrapper: MPI                             513       0.121    0.000237
# timer overhead/call (sec): 1.16e-07
# timer overhead/call (sec): 1.02e-09 (sample=1024)
#  !!! WARNING --- trunc[5,15]/Q  has non-analytic point in quadrature interval [ 0 , 15 ] --- WARNING !!!
#  Exact numerical integration needs integrands that are analytic within every finite element.
#  Matrix elements will be discretization dependent and non-systematic errors may appear
#     - errors may be acceptably low, but convergence with order may be inconsistent
#     - for consistent convergence place element boundaries on non-analytic points
#
#
#  !!! WARNING --- trunc[5,15]/Q  has non-analytic point in quadrature interval [ 0 , 15 ] --- WARNING !!!
#
#                  !!! Limit=1 reached, no further warnings:  trunc[5,15]/Q  has ... !!!
#
#
# Parallel layout of Interaction+H0
# total load =82.9544     (pre-receive)->[oper]->(post-send)    dataSize{#blocks}
# Process no 0,	loadDelta=  5%,	blocks= 40, ()->[0]->(1)	Send= 39{2}
# Process no 1,	loadDelta=  2%,	blocks= 33, ()->[1]->(0,2)	Send= 78{4}
# Process no 2,	loadDelta=  2%,	blocks= 27, ()->[2]->(1,3)	Send= 78{4}
# Process no 3,	loadDelta=-10%,	blocks= 28, ()->[3]->(2)	Send= 39{2}
#
# Parallel layout of mapFromFullToContracted
# total load =8.9489     (pre-receive)->[oper]->(post-send)    dataSize{#blocks}
# Process no 0,	loadDelta=  4%,	blocks= 14, ()->[0]->()
# Process no 1,	loadDelta=-13%,	blocks= 11, ()->[1]->(0)	Send= 21{6}
# Process no 2,	loadDelta=-18%,	blocks= 9, ()->[2]->(0)	Send= 21{5}
# Process no 3,	loadDelta= 27%,	blocks= 10, ()->[3]->(0)	Send= 25{5}
#
# Parallel layout of mapToFullFromContracted
# total load =9.533     (pre-receive)->[oper]->(post-send)    dataSize{#blocks}
# Process no 0,	loadDelta= 13%,	blocks= 14, ()->[0]->()
# Process no 1,	loadDelta= -9%,	blocks= 11, (0)->[1]->()	Recv= 21{6}
# Process no 2,	loadDelta=-15%,	blocks= 9, (0)->[2]->()	Recv= 21{5}
# Process no 3,	loadDelta= 12%,	blocks= 10, (0)->[3]->()	Recv= 25{5}
#
#  *** non-constant parameters in operator "Interaction+H0": iLaserAz[t], iLaserAx[t], iLaserAy[t] ***
#
#  !!! --- CURRENT WARNINGS (see /home/user/TIPTOE/850nm/350_nm_Drive_lower_Int//0/WARNINGS) --- !!!
#                   0: trunc[5,15]/Q  has non-analytic point in quadrature interval [ 0 , 15 ]
#                  12: Absorption:upper OBSOLESCENT -- change name to "radius"
#                  24: Axis:lower end OBSOLESCENT -- change name to "lowerEnd"
#                  30: Axis:upper end OBSOLESCENT -- change name to "upperEnd"
#  *** Initial state calculation ***
#  *** initial state: eigenvector 1 of time-evolution at t=-585.130885138 ***
#
#
#  ===  Start Propagation - timing  ==============================================
#
#                      File: Name                          calls   cpu(total)   cpu/call [samp]
#                 run_trecx: all                               7        20.4        2.92
#              initialState: create                            1        16.8        16.8
#                mpiWrapper: MPI                            9860        13.2     0.00134
#                 run_trecx: setup                             3        2.75       0.915
#                 run_trecx: buildOperators                    1        1.18        1.18
#                     tRecX: expecOps                          1       0.434       0.434
# timer overhead/call (sec): 6.69e-08
# timer overhead/call (sec): 1.32e-09 (sample=1024)
#
#
#  ===  PROPAGATION PARAMETERS  ==================================================
#
#     begin end print   store fixStep   accuracy cutEnergy method
#      ----   --   ---   -----   -----   --------   -------   ----
#    -585.1 315 45.01 0.04174    0.04 no control        50    RK4
#
#  ***  Expectation values will only be computed at TimePropagation:print times ***
#
#
#  ===  TIME PROPAGATION (/home/user/TIPTOE/850nm/350_nm_Drive_lower_Int//0/)  ===
#
#         <Occ{H0:0}>: |0><0| of hamiltonian at hierarchy Phi.Eta.Rn.Rn
#         <Occ{H0:1}>: |1><1| of hamiltonian at hierarchy Phi.Eta.Rn.Rn
#         <Occ{H0:2}>: |2><2| of hamiltonian at hierarchy Phi.Eta.Rn.Rn
#         <Occ{H0:3}>: |3><3| of hamiltonian at hierarchy Phi.Eta.Rn.Rn
#         <Occ{H0:4}>: |4><4| of hamiltonian at hierarchy Phi.Eta.Rn.Rn
#         <Occ{H0:5}>: |5><5| of hamiltonian at hierarchy Phi.Eta.Rn.Rn
#
#        Initial <H0>: -0.49999176498036
#
#       CPU   (%)     Time <Ovr(Phi.Eta.R...>              <H0> <Occ{H0:0}>         <Occ{H0:1}>         <Occ{H0:2}>         <Occ{H0:3}>         <Occ{H0:4}>         <Occ{H0:5}>
#      -----   --   ------   ----------------   ---------------   ---------   -----------------   -----------------   -----------------   -----------------   -----------------
#          0    0 -585.131                  1 -0.49999176498036           1 9.6171501027783e-21 -8.386818847065e-18 6.6167214611033e-21 4.6850547495958e-22 1.5440204937006e-17
#      7.166    5 -540.121   0.99999999900015 -0.49999176416967 0.99999999834742 4.3612632923104e-10 -1.6654045384261e-19 1.0128610526202e-19  7.470824232012e-11 4.3185369805972e-17
#      13.97   10 -495.111    0.9999999980003 -0.49999126443593 0.99999882848852 9.2938271821298e-07  8.1873712148135e-12 2.6382916272824e-12 1.0305968749628e-07  3.542734359009e-13
#      22.82   15 -450.101   0.99999999700027 -0.49999148410731 0.99999941572786 3.8673301029593e-07  1.5512902220709e-11 7.6847843192967e-14 6.4870528322614e-08 8.3710971783614e-15
#      31.36   20 -405.091   0.99999999600019 -0.49999176297378 0.99999999598287 7.6926378311735e-13  1.5762651262507e-11  2.971653778638e-15 2.5485484942955e-13 -6.3841662347592e-16
#      34.52   25 -360.081   0.99999999500083 -0.49999176247459 0.99999999498482 1.5014288540558e-16  1.6004891491642e-11 2.9725340236534e-15 4.1683344151717e-15  1.2575612504118e-15
#      37.93   30 -315.071   0.99999999400124 -0.49999176197461 0.99999999398509 1.5067118453573e-16  1.6141607423131e-11 2.9729330113632e-15 4.2208224420293e-15 -1.6850843358704e-15
#      40.76   35 -270.061   0.99999999300094 -0.49999176146424  0.9999999929644 1.2182939268981e-11  1.5910689950563e-11  2.973320603486e-15  2.598319066172e-12  2.0454867386296e-15
#       50.3   40 -225.051   0.99999999200077 -0.49999162929697 0.99999973030048 1.6044860191754e-07  1.5332728415535e-11 4.7760520635708e-15 3.1442132612245e-08 -3.0180259826412e-14
#      53.42   45 -180.041   0.99999999100115  -0.4999783892059 0.99997185493639 1.9018848786907e-05  6.5328728534445e-10 2.5716595128661e-10  3.111729918728e-06   2.122480044108e-11
#      54.93   50 -135.031   0.99999998998105 -0.49496362271385 0.98993665692226  0.0061938357618872  3.0834223901005e-05 1.8039459165857e-05  0.0011898017462004  2.8471688277415e-06
#      57.42   55 -90.0209   0.99999998854791 -0.42897120675558 0.86912829383042   0.062289826778688     0.00420571123348  0.0020771283801044   0.015398913541953  0.00052233289210658
#      59.76   60 -45.0109   0.99999852682824 -0.38485355800021 0.79430908586211   0.085728050697949   0.0098848899387106  0.0048413826222408   0.023981394551575   0.0012424721642897
#      60.83   65 -0.000885138   0.99997774139034 -0.49332061400294 0.98366120393999   0.012962174927569  0.00085533298077867 0.00049443328544304 0.00083830461530325  1.9791811675359e-05
#      64.25   70      45.0091    0.9994061304917 -0.38567676482186 0.79481853745485   0.086643828860042   0.0091950859483112  0.0046014632746751   0.023488587355014   0.0011365814900471
#      65.97   75      90.0191   0.99913129466259  -0.4284865208448 0.86836129541452   0.062126966308546   0.0040016322467512  0.0021387799352068   0.015319798583451  0.00046919046081742
#      67.08   80      135.029   0.99903917747916 -0.49445772270629 0.98890631647804   0.006291895816887  9.6688329971173e-05 1.6332562546608e-05  0.0011089644823744  5.6820957962858e-06
#      70.83   85      180.039   0.99902422371569  -0.4994723472487 0.99895662208648 1.7305904201129e-05   1.417397454849e-05 1.8951222165872e-05  1.345307692664e-06  1.3661748703845e-07
#      75.22   90      225.049   0.99901636129423 -0.49948160884978 0.99897545557254 2.8467324354529e-07  1.4090567327603e-05 1.8685026521689e-05 4.6226445830491e-06  2.1045899688235e-07
#      76.26   95      270.059    0.9990140593768 -0.49948213242883 0.99897646339467 1.5203006321483e-07  1.4088718900855e-05 1.8262946874747e-05 3.8682291984831e-06  2.1279842143711e-07
#      77.21  100      315.025   0.99901438453079 -0.49948215006612 0.99897646673562 1.5597988029474e-07  1.4094089659296e-05  1.874847003435e-05  3.776698469586e-06  2.1013782531143e-07
#
#
#  ===  Info  ====================================================================
#    Imaginary expectation values
#    Operator: value where maximal imaginary part appears
#    Occ{H0:1}: (0.0866,4.01e-06)
#    Occ{H0:3}: (0.00214,-1.35e-05)
#    Occ{H0:4}: (0.0235,-4.77e-05)
#    Occ{H0:5}: (0.000469,-1.08e-05)
#
#    Complex expectation values can appear with complex scaling.
#    Physical interpretation of expecation values is limited
#    to within the magnitude of the imaginary part
#  ================================================================
#
#  *** compute iSurff spectral decomposition for size=858 ***
#
#  TimePropagator RK4: calls=90076, fixed step=0.04
#
#  !!! --- CURRENT WARNINGS (see /home/user/TIPTOE/850nm/350_nm_Drive_lower_Int//0/WARNINGS) --- !!!
#                   0: trunc[5,15]/Q  has non-analytic point in quadrature interval [ 0 , 15 ]
#                  12: Absorption:upper OBSOLESCENT -- change name to "radius"
#                  24: Axis:lower end OBSOLESCENT -- change name to "lowerEnd"
#                  30: Axis:upper end OBSOLESCENT -- change name to "upperEnd"
#                   0: trunc[5,15]/Q  has non-analytic point in quadrature interval [ 0 , 15 ]
#
#
#  ===  End Propagation - timing  ================================================
#
#                      File: Name                          calls   cpu(total)   cpu/call [samp]
#                 run_trecx: all                               7        98.1          14
#                mpiWrapper: MPI                          933359        68.4    7.33e-05
#              initialState: create                            1        16.8        16.8
#                 run_trecx: setup                             3        2.75       0.915
#                 run_trecx: buildOperators                    1        1.18        1.18
#                     tRecX: expecOps                          1       0.434       0.434
#            spectrumISurff: iSurff                            1     0.00041     0.00041
#                 run_trecx: timePropagate                     1    1.17e-06    1.17e-06
# timer overhead/call (sec): 5.76e-08
# timer overhead/call (sec): 1.17e-09 (sample=1024)
#
#
#  *** further output on /home/user/TIPTOE/850nm/350_nm_Drive_lower_Int//0/S_Rn/outf ***
#  Master host = mpq6p100 (4 processes)
#
#
#
#  ===  DISCRETIZATION AND INCOMING FLUX  ========================================
#
#                Name: Phi.Eta.surfRn.ValDerRn
#         Coordinates: Phi.Eta.kRn
#
#           source(s): /home/user/TIPTOE/850nm/350_nm_Drive_lower_Int//0/surface_Rn
#         end,turnOff: inft, ABRUPT (Caution)
#
#    axis Points      Emin  Emax       spacing
#      --   ----   -------   ---   -----------
#     kRn     64 7.178e-05 0.294 k-equidistant
#
#            Surfaces: default (at complex scaling radius)
#
#
#  ===  OPERATORS  ===============================================================
#
#         Hamiltonian: 1/2<<Laplacian>>-<1><1><trunc[5,15]/Q>
#           Region Rn: only spectral amplitudes
#         Interaction: iLaserAz[t]<<D/DZ>>+iLaserAx[t]<<D/DX>>+iLaserAy[t]<<D/DY>>
#           Region Rn:
#          HamInitial: H(t=Begin)
#
#  Expectation Values: Occupation[0,1,2,3,4,5]
#          Projection: default
#  --- potentials truncated by trunc[0,15] ---
#
#
#
#  ===  Laser  ===================================================================
#
#    polAxis Shape Intens(W/cm2) lambda(nm) photon(eV)  FWHM  begin    end phiCEO
#      -----   ---   -----------   --------   --------   ---   ----   ----   ----
#    [1 0 0]  cos8       7.5e+13        850      1.459 117.2   -315    315
#    [1 0 0]  cos8         6e+09        350      3.542 38.45 -585.1 -378.5  1.571
#
#  ponderomotive potential (eV): 5.06
#
#       Initial state: atBegin for operator H(t=Begin)
#
#
#  ===  OUTPUT  ==================================================================
#           Directory: /home/user/TIPTOE/850nm/350_nm_Drive_lower_Int//0/S_Rn/
#
#
#
#
#  ===  End of Input - timing  ===================================================
#
#                      File: Name                          calls   cpu(total)   cpu/call [samp]
#                 run_trecx: all                              10        98.8        9.88
#                mpiWrapper: MPI                          933973        68.4    7.32e-05
#              initialState: create                            1        16.8        16.8
#                 run_trecx: setup                             6         3.5       0.583
#                 run_trecx: buildOperators                    1        1.18        1.18
#                     tRecX: expecOps                          1       0.434       0.434
#            spectrumISurff: iSurff                            1     0.00041     0.00041
#                 run_trecx: timePropagate                     1    1.17e-06    1.17e-06
# timer overhead/call (sec): 6.51e-08
# timer overhead/call (sec): 1.01e-09 (sample=1024)
#  *** Only integration of source - no Propagation operator defined ***
#
#  !!! --- CURRENT WARNINGS (see /home/user/TIPTOE/850nm/350_nm_Drive_lower_Int//0/WARNINGS) --- !!!
#                   0: trunc[5,15]/Q  has non-analytic point in quadrature interval [ 0 , 15 ]
#                  28: Absorption:upper OBSOLESCENT -- change name to "radius"
#                  56: Axis:lower end OBSOLESCENT -- change name to "lowerEnd"
#                  70: Axis:upper end OBSOLESCENT -- change name to "upperEnd"
#                   0: trunc[5,15]/Q  has non-analytic point in quadrature interval [ 0 , 15 ]
#  *** initial state: ZERO ***
#
#
#  ===  Start Propagation - timing  ==============================================
#
#                      File: Name                          calls   cpu(total)   cpu/call [samp]
#                 run_trecx: all                              13        99.1        7.62
#                mpiWrapper: MPI                          933980        68.4    7.32e-05
#              initialState: create                            2        16.8        8.39
#                 run_trecx: setup                             6        3.61       0.602
#                 run_trecx: buildOperators                    2        1.18       0.589
#                     tRecX: expecOps                          1       0.434       0.434
#            spectrumISurff: iSurff                            1     0.00041     0.00041
#                 run_trecx: timePropagate                     1    1.17e-06    1.17e-06
# timer overhead/call (sec): 4.61e-08
# timer overhead/call (sec): 9.84e-10 (sample=1024)
#
#
#  ===  PROPAGATION PARAMETERS  ==================================================
#
#     begin end print   store fixStep   accuracy cutEnergy method
#      ----   --   ---   -----   -----   --------   -------   ----
#    -585.1 315 45.01 0.04174 0.04174 no control        50  euler
#
#
#
#  ===  TIME PROPAGATION (/home/user/TIPTOE/850nm/350_nm_Drive_lower_Int//0/S_Rn/)
#
#           <Overlap>: <1><1><GridWeight> at hierarchy Phi.Eta.specRn.kRn
#
#   Initial <Overlap>: 0
#
#       CPU   (%)     Time <Ovr(Phi.Eta.s...> <Overlap>
#      -----   --   ------   ----------------   -------
#          0    0 -585.131                  0         0
#       4.24    5 -540.121 2.579900284651e-07 4.7142939117094e-11
#      8.283   10 -495.111 1.0451041059332e-07 3.8050662445092e-11
#      12.12   15 -450.101 1.1788230479533e-07 3.7076557458735e-11
#      16.28   20 -405.091 2.4870645188913e-07 4.8004309639699e-11
#      20.78   25 -360.081 3.2482301057294e-08 3.6449988972629e-11
#      25.83   30 -315.071 2.4347627036462e-07 4.2206323337161e-11
#      30.75   35 -270.061 9.5078471331007e-08  4.236895692516e-11
#      34.91   40 -225.051 1.5022555850816e-07 3.7424878310559e-11
#      39.33   45 -180.041  1.991690442138e-07 4.4250540585009e-11
#      43.05   50 -135.031 3.7604854031351e-07 2.5009413300177e-10
#      46.56   55 -90.0209 4.3210928222573e-06 2.3668860348123e-09
#      50.01   60 -45.0109  0.0022967477018632 1.3429814664222e-06
#      53.22   65 -0.000885138   0.025293383597583 2.1611052057701e-05
#      55.85   70      45.0091    0.87997825177092 0.00059214558432633
#      59.18   75      90.0191    0.92069246078816 0.00086908699602162
#      61.93   80      135.029    0.91374431409192 0.00096329859223249
#       65.4   85      180.039    0.85248714392466 0.00097856216623096
#      71.17   90      225.049    0.83167112666541 0.00098645157597494
#      76.04   95      270.059    0.82379838396141 0.00098882853209569
#      79.09  100      315.025      0.813054071028 0.00098851317031355
#  *** adding iSurff correction ***
#  *** Photo-electron amplitudes on /home/user/TIPTOE/850nm/350_nm_Drive_lower_Int//0/S_Rn/ampl ***
#
#  TimePropagator euler: calls=0, fixed step=0.041741740070742
#
#  !!! --- CURRENT WARNINGS (see /home/user/TIPTOE/850nm/350_nm_Drive_lower_Int//0/WARNINGS) --- !!!
#                   0: trunc[5,15]/Q  has non-analytic point in quadrature interval [ 0 , 15 ]
#                  28: Absorption:upper OBSOLESCENT -- change name to "radius"
#                  56: Axis:lower end OBSOLESCENT -- change name to "lowerEnd"
#                  70: Axis:upper end OBSOLESCENT -- change name to "upperEnd"
#                   0: trunc[5,15]/Q  has non-analytic point in quadrature interval [ 0 , 15 ]
#
#
#  ===  End Propagation - timing  ================================================
#
#                      File: Name                          calls   cpu(total)   cpu/call [samp]
#                 run_trecx: all                              13         178        13.7
#                mpiWrapper: MPI                         1106184        98.4    8.89e-05
#              initialState: create                            2        16.8        8.39
#                 run_trecx: setup                             6        3.61       0.602
#                 run_trecx: buildOperators                    2        1.18       0.589
#                     tRecX: expecOps                          1       0.434       0.434
#            spectrumISurff: iSurff                            1     0.00041     0.00041
#                 run_trecx: timePropagate                     2    1.37e-06    6.86e-07
# timer overhead/call (sec): 5.26e-08
# timer overhead/call (sec): 1.12e-09 (sample=1024)
#
#
#  *** further output on /home/user/TIPTOE/850nm/350_nm_Drive_lower_Int//0/outspec ***
#  ***  Integral of Spectrum: 0  [ Phi.Eta.specRn.kRn ] ***
#  ***    spectra file /home/user/TIPTOE/850nm/350_nm_Drive_lower_Int//0/S_Rn/spec_total ***
#  *** added amplitude file /home/user/TIPTOE/850nm/350_nm_Drive_lower_Int//0/S_Rn/ampl ***
#  ***    spectra file /home/user/TIPTOE/850nm/350_nm_Drive_lower_Int//0/spec_total ***
#
#
#  ===  Evaluation of Expectation Values in the Unbounded Region  ================
#
#                              Definition            <Op> Validity
#      ----------------------------------   -------------   ------
#                      <1><1><GridWeight> 0.0009901133748
#                    <1><Q><GridWeight*Q> 0.0002481315855
#     <cos(Q)><sqrt(1-Q*Q)><GridWeight*Q>               0
#     <sin(Q)><sqrt(1-Q*Q)><GridWeight*Q>               0
#
#  !!! WARNING --- this feature is still in developmental stages, differentials cannot be evaluated and operators require a very specific format --- WARNING !!!
#
#
#  *** spectra calculated from amplitude file(s), for recomputing amplitudes -recompute ***
#
#
#  ===  Final - timing  ==========================================================
#
#                      File: Name                          calls   cpu(total)   cpu/call [samp]
#                 run_trecx: all                              14         179        12.8
#                mpiWrapper: MPI                         1106227        98.4    8.89e-05
#              initialState: create                            2        16.8        8.39
#                 run_trecx: setup                             7        4.17       0.595
#                 run_trecx: buildOperators                    2        1.18       0.589
#                     tRecX: expecOps                          1       0.434       0.434
#            spectrumISurff: iSurff                            1     0.00041     0.00041
#                 run_trecx: timePropagate                     2    1.37e-06    6.86e-07
# timer overhead/call (sec): 5.59e-08
# timer overhead/call (sec): 1.17e-09 (sample=1024)
#
#
#  *** Description of input on file /home/user/tRecX/tRecX.doc ***
#
#
#  ===  done - /home/user/TIPTOE/850nm/350_nm_Drive_lower_Int//0/S_Rn/  ==========
#
#  !!! --- CURRENT WARNINGS (see /home/user/TIPTOE/850nm/350_nm_Drive_lower_Int//0/WARNINGS) --- !!!
#                   0: trunc[5,15]/Q  has non-analytic point in quadrature interval [ 0 , 15 ]
#                  42: Absorption:upper OBSOLESCENT -- change name to "radius"
#                  84: Axis:lower end OBSOLESCENT -- change name to "lowerEnd"
#                 105: Axis:upper end OBSOLESCENT -- change name to "upperEnd"
#                   1: this feature is still in developmental stages, differentials cannot be evaluated...
#                   0: trunc[5,15]/Q  has non-analytic point in quadrature interval [ 0 , 15 ]
#
#  === tRecX done ==================================================
# 0
#
#
#  -> tRecX (v 2.0) (C) 2015-2024 Armin Scrinzi (licenced under GPLv2) <-
#
#  Build: May 16 2024 10:37:10, git hash 658b04d, type "Parallel"
#
#
#
#  *** further output on /home/user/TIPTOE/850nm/350_nm_Drive_lower_Int//1/outf ***
#
#
#  ===  Date [06/26 13:10:28] Photoconductive Sampling -  ========================
#
#  !!! WARNING --- Axis:lower end OBSOLESCENT -- change name to "lowerEnd" --- WARNING !!!
#
#  !!! WARNING --- Axis:upper end OBSOLESCENT -- change name to "upperEnd" --- WARNING !!!
#
#  !!! WARNING --- Axis:lower end OBSOLESCENT -- change name to "lowerEnd" --- WARNING !!!
#
#                  !!! Limit=1 reached, no further warnings: Axis:lower end OBSOL... !!!
#
#  !!! WARNING --- Axis:upper end OBSOLESCENT -- change name to "upperEnd" --- WARNING !!!
#
#                  !!! Limit=1 reached, no further warnings: Axis:upper end OBSOL... !!!
#
#  !!! WARNING --- Absorption:upper OBSOLESCENT -- change name to "radius" --- WARNING !!!
#
#  !!! WARNING --- Absorption:upper OBSOLESCENT -- change name to "radius" --- WARNING !!!
#
#                  !!! Limit=1 reached, no further warnings: Absorption:upper OBS... !!!
#
#  Master host = mpq6p100 (4 processes)
#
#  *** OK inverse overlap: S Sinv, error=2.2e-16 ... Sinv S, error=2.2e-16 (Phi.Eta.Rn.Rn) ***
#
#
#  ===  DVR --- DISCRETIZATION  ==================================================
#
#                Name: Phi.Eta.Rn
#
#    Axis maxCoeff from       to order                basis      absorption: eta,inner
#      --   ------   --   ------   ---   ------------------   ------------------------
#     Phi        1    0    6.283     1               cosSin
#     Eta       22   -1        1    22   assocLegendre{Phi}
#      Rn       38    0 15|Infty    20 polynomial/polExp... ECS:(0.995,0.0998)[-15,15]
#  Full basis name(s): polynomial/polExp[0.5]
#          total size: 858
#
#            Surfaces: default (at complex scaling radius)
#
#
#  ===  OPERATORS  ===============================================================
#
#         Hamiltonian: 1/2<<Laplacian>>-<1><1><trunc[5,15]/Q>
#         Interaction: iLaserAz[t]<<D/DZ>>+iLaserAx[t]<<D/DX>>+iLaserAy[t]<<D/DY>>
#          HamInitial: H(t=Begin)
#
#  Expectation Values: Occupation[0,1,2,3,4,5]
#          Projection: default
#  --- potentials truncated by trunc[0,15] ---
#
#
#
#  ===  Laser  ===================================================================
#
#    polAxis Shape Intens(W/cm2) lambda(nm) photon(eV)  FWHM  begin    end phiCEO
#      -----   ---   -----------   --------   --------   ---   ----   ----   ----
#    [1 0 0]  cos8       7.5e+13        850      1.459 117.2   -315    315
#    [1 0 0]  cos8         6e+09        350      3.542 38.45 -547.3 -340.7  1.571
#
#  ponderomotive potential (eV): 5.06
#
#  *** Multi-color pulse, OptCyc is for 1st color, value=117.215 (au) ***
#       Initial state: atBegin for operator H(t=Begin)
#
#
#  ===  OUTPUT  ==================================================================
#           Directory: /home/user/TIPTOE/850nm/350_nm_Drive_lower_Int//1/
#
#  *** Description of input on file /home/user/tRecX/tRecX.doc ***
#
#
#
#  ===  End of Input - timing  ===================================================
#
#                      File: Name                          calls   cpu(total)   cpu/call [samp]
#                 run_trecx: all                               4        1.84        0.46
#                 run_trecx: setup                             3        1.44        0.48
#                mpiWrapper: MPI                             513       0.482    0.000939
# timer overhead/call (sec): 8.41e-08
# timer overhead/call (sec): 1.12e-09 (sample=1024)
#  !!! WARNING --- trunc[5,15]/Q  has non-analytic point in quadrature interval [ 0 , 15 ] --- WARNING !!!
#  Exact numerical integration needs integrands that are analytic within every finite element.
#  Matrix elements will be discretization dependent and non-systematic errors may appear
#     - errors may be acceptably low, but convergence with order may be inconsistent
#     - for consistent convergence place element boundaries on non-analytic points
#
#
#  !!! WARNING --- trunc[5,15]/Q  has non-analytic point in quadrature interval [ 0 , 15 ] --- WARNING !!!
#
#                  !!! Limit=1 reached, no further warnings:  trunc[5,15]/Q  has ... !!!
#
#
# Parallel layout of Interaction+H0
# total load =87.198000000001     (pre-receive)->[oper]->(post-send)    dataSize{#blocks}
# Process no 0,	loadDelta=  9%,	blocks= 40, ()->[0]->(1)	Send= 39{2}
# Process no 1,	loadDelta= -8%,	blocks= 27, ()->[1]->(0,2)	Send= 78{4}
# Process no 2,	loadDelta=  0%,	blocks= 27, ()->[2]->(1,3)	Send= 78{4}
# Process no 3,	loadDelta=  0%,	blocks= 34, ()->[3]->(2)	Send= 39{2}
#
# Parallel layout of mapFromFullToContracted
# total load =8.9104     (pre-receive)->[oper]->(post-send)    dataSize{#blocks}
# Process no 0,	loadDelta=  6%,	blocks= 14, ()->[0]->()
# Process no 1,	loadDelta=-25%,	blocks= 9, ()->[1]->(0)	Send= 17{5}
# Process no 2,	loadDelta=-18%,	blocks= 9, ()->[2]->(0)	Send= 20{5}
# Process no 3,	loadDelta= 37%,	blocks= 12, ()->[3]->(0)	Send= 30{6}
#
# Parallel layout of mapToFullFromContracted
# total load =9.7243999999996     (pre-receive)->[oper]->(post-send)    dataSize{#blocks}
# Process no 0,	loadDelta= 16%,	blocks= 14, ()->[0]->()
# Process no 1,	loadDelta=-22%,	blocks= 9, (0)->[1]->()	Recv= 17{5}
# Process no 2,	loadDelta=-13%,	blocks= 9, (0)->[2]->()	Recv= 20{5}
# Process no 3,	loadDelta= 19%,	blocks= 12, (0)->[3]->()	Recv= 30{6}
#
#  *** non-constant parameters in operator "Interaction+H0": iLaserAz[t], iLaserAx[t], iLaserAy[t] ***
#
#  !!! --- CURRENT WARNINGS (see /home/user/TIPTOE/850nm/350_nm_Drive_lower_Int//1/WARNINGS) --- !!!
#                   0: trunc[5,15]/Q  has non-analytic point in quadrature interval [ 0 , 15 ]
#                  12: Absorption:upper OBSOLESCENT -- change name to "radius"
#                  24: Axis:lower end OBSOLESCENT -- change name to "lowerEnd"
#                  30: Axis:upper end OBSOLESCENT -- change name to "upperEnd"
#  *** Initial state calculation ***
#  *** initial state: eigenvector 1 of time-evolution at t=-547.330885138 ***
#
#
#  ===  Start Propagation - timing  ==============================================
#
#                      File: Name                          calls   cpu(total)   cpu/call [samp]
#                 run_trecx: all                               7        12.7        1.82
#              initialState: create                            1        9.25        9.25
#                mpiWrapper: MPI                            9860        6.46    0.000655
#                 run_trecx: setup                             3        2.87       0.956
#                 run_trecx: buildOperators                    1       0.267       0.267
#                     tRecX: expecOps                          1        0.11        0.11
# timer overhead/call (sec): 7.06e-08
# timer overhead/call (sec): 1.13e-09 (sample=1024)
#
#
#  ===  PROPAGATION PARAMETERS  ==================================================
#
#     begin end print   store fixStep   accuracy cutEnergy method
#      ----   --   ---   -----   -----   --------   -------   ----
#    -547.3 315 43.12 0.04174    0.04 no control        50    RK4
#
#  ***  Expectation values will only be computed at TimePropagation:print times ***
#
#
#  ===  TIME PROPAGATION (/home/user/TIPTOE/850nm/350_nm_Drive_lower_Int//1/)  ===
#
#         <Occ{H0:0}>: |0><0| of hamiltonian at hierarchy Phi.Eta.Rn.Rn
#         <Occ{H0:1}>: |1><1| of hamiltonian at hierarchy Phi.Eta.Rn.Rn
#         <Occ{H0:2}>: |2><2| of hamiltonian at hierarchy Phi.Eta.Rn.Rn
#         <Occ{H0:3}>: |3><3| of hamiltonian at hierarchy Phi.Eta.Rn.Rn
#         <Occ{H0:4}>: |4><4| of hamiltonian at hierarchy Phi.Eta.Rn.Rn
#         <Occ{H0:5}>: |5><5| of hamiltonian at hierarchy Phi.Eta.Rn.Rn
#
#        Initial <H0>: -0.49999176498036
#
#       CPU   (%)     Time <Ovr(Phi.Eta.R...>              <H0> <Occ{H0:0}>         <Occ{H0:1}>         <Occ{H0:2}>         <Occ{H0:3}>         <Occ{H0:4}>         <Occ{H0:5}>
#      -----   --   ------   ----------------   ---------------   ---------   -----------------   -----------------   -----------------   -----------------   -----------------
#          0    0 -547.331                  1 -0.49999176498036           1 9.6171501027783e-21 -8.386818847065e-18 6.6167214611033e-21 4.6850547495958e-22 1.5440204937006e-17
#      1.915    5 -504.211   0.99999999904192 -0.49999176437029 0.99999999873132 2.4504212739561e-10 1.5424171300818e-17 9.3920370619742e-20 3.0118995977433e-11 -5.6666193002253e-17
#      3.197   10 -461.091   0.99999999808386 -0.49999019914276 0.99999666823133 2.3036669392801e-06 1.1678226495944e-11 5.4077641195176e-12 3.5472239516284e-07 -1.8547445544324e-13
#      5.143   15 -417.971   0.99999999712547 -0.49999021964081 0.99999681615076 2.0820304535237e-06 2.3245808437978e-11 2.1702432234279e-12 3.6050415036555e-07 -2.5786054764225e-13
#      6.069   20 -374.851   0.99999999616804 -0.49999176299971 0.99999999603597 7.0671664043172e-11 1.6146569025901e-11 2.9715921002006e-15 1.3929165683976e-11 -6.8220621425024e-16
#      7.688   25 -331.731   0.99999999520929 -0.49999176257911 0.99999999519347 1.5016454158254e-16 1.5811443301584e-11 2.9724512524808e-15 4.1626271635281e-15  1.8070401450073e-15
#      9.069   30 -288.611   0.99999999425144 -0.49999176210002 0.99999999423551 9.4934138654407e-17 1.5928654195355e-11 2.9728864615358e-15 3.6466712072556e-15 -2.1843975009363e-15
#      10.35   35 -245.491   0.99999999329374 -0.49999175763986 0.99999998520556 5.1278679295764e-09 1.6150113737275e-11 3.1604045455309e-15 9.4335277652831e-10  2.1150451224183e-16
#      12.28   40 -202.371   0.99999999233488 -0.49997621709885 0.99996882264495 1.9427724938147e-05 1.8681426914441e-10  1.668084282133e-10 3.6957687656548e-06  2.0434892282302e-11
#      13.43   45 -159.251   0.99999999137381 -0.49922024916649 0.99845496946959 0.00095985367075687 6.3189719780646e-07  3.984778668927e-07 0.00018319292806256  6.2876018439127e-08
#      14.29   50 -116.131   0.99999999034335 -0.49964391298381 0.99919695795631   0.000618323303434 1.4846553253626e-06 6.1006375608073e-07 7.6134666960749e-05  4.5314850049526e-08
#      15.38   55 -73.0109   0.99999998846972 -0.43572101908848 0.88011550823326   0.058604965240462  0.0037481704217842  0.0018622086709952   0.014173018386765  0.00044454347234614
#      17.55   60 -29.8909   0.99998669658126 -0.18117497708165  0.5537774239309   0.090874435715618   0.027438211969007  0.0073961371881383   0.036693575682104   0.0057327770859412
#      18.48   65  13.2291   0.99983953532099 -0.33655297617849 0.72355229382274   0.091670858613017   0.016139466712679   0.005722783750859   0.033139663413668    0.002875330178885
#      19.38   70  56.3491   0.99942175950982 -0.49372399559263 0.98651911520239  0.0089606039137883 0.00037415942219791 0.00019567966582558  0.0009563577818648  1.1385889949067e-05
#      20.32   75  99.4691   0.99911202476264 -0.46625516907785 0.93484210318194   0.035033465107508  0.0010216834873454 0.00063558546845498  0.0077203379770085  0.00015819078765182
#      21.17   80  142.589    0.9990352427455 -0.49521919843863 0.99045717565564  0.0052340692817042 2.0498799266086e-06 3.1805303895069e-05  0.0010720110167497  3.8762006525021e-07
#      21.98   85  185.709   0.99902281349157  -0.4994432078604 0.99889635933435 4.6167788787682e-05 1.4103728533069e-05 1.8984432101811e-05 2.2519976110379e-05  1.6750104612574e-07
#      23.48   90  228.829   0.99901588473831  -0.4994821454927 0.99897655752711 4.9811301952096e-08 1.4083659661112e-05 1.8566397798845e-05 3.8604793238329e-06  2.1606029032233e-07
#      24.44   95  271.949   0.99901400413062 -0.49948211299322 0.99897642402302 1.5342852262782e-07 1.4082558817329e-05 1.8276042962709e-05 3.8616460740777e-06  2.1328491732823e-07
#      25.17  100  315.025   0.99901433545685 -0.49948212851679  0.9989764248955 1.5613745834166e-07 1.4088899442675e-05 1.8746664953844e-05 3.7762464588915e-06  2.1020286410187e-07
#
#
#  ===  Info  ====================================================================
#    Imaginary expectation values
#    Operator: value where maximal imaginary part appears
#    Occ{H0:1}: (0.0917,8.11e-06)
#    Occ{H0:2}: (0.0161,-1.6e-06)
#    Occ{H0:3}: (0.00572,-2.63e-05)
#    Occ{H0:4}: (0.0331,-0.000166)
#    Occ{H0:5}: (0.00288,3.47e-05)
#
#    Complex expectation values can appear with complex scaling.
#    Physical interpretation of expecation values is limited
#    to within the magnitude of the imaginary part
#  ================================================================
#
#  *** compute iSurff spectral decomposition for size=858 ***
#
#  TimePropagator RK4: calls=86236, fixed step=0.04
#
#  !!! --- CURRENT WARNINGS (see /home/user/TIPTOE/850nm/350_nm_Drive_lower_Int//1/WARNINGS) --- !!!
#                   0: trunc[5,15]/Q  has non-analytic point in quadrature interval [ 0 , 15 ]
#                  12: Absorption:upper OBSOLESCENT -- change name to "radius"
#                  24: Axis:lower end OBSOLESCENT -- change name to "lowerEnd"
#                  30: Axis:upper end OBSOLESCENT -- change name to "upperEnd"
#                   0: trunc[5,15]/Q  has non-analytic point in quadrature interval [ 0 , 15 ]
#
#
#  ===  End Propagation - timing  ================================================
#
#                      File: Name                          calls   cpu(total)   cpu/call [samp]
#                 run_trecx: all                               7        38.2        5.45
#                mpiWrapper: MPI                          893999        17.7    1.98e-05
#              initialState: create                            1        9.25        9.25
#                 run_trecx: setup                             3        2.87       0.956
#                 run_trecx: buildOperators                    1       0.267       0.267
#                     tRecX: expecOps                          1        0.11        0.11
#            spectrumISurff: iSurff                            1    0.000137    0.000137
#                 run_trecx: timePropagate                     1    2.36e-07    2.36e-07
# timer overhead/call (sec): 8.84e-08
# timer overhead/call (sec): 1.25e-09 (sample=1024)
#
#
#  *** further output on /home/user/TIPTOE/850nm/350_nm_Drive_lower_Int//1/S_Rn/outf ***
#  Master host = mpq6p100 (4 processes)
#
#
#
#  ===  DISCRETIZATION AND INCOMING FLUX  ========================================
#
#                Name: Phi.Eta.surfRn.ValDerRn
#         Coordinates: Phi.Eta.kRn
#
#           source(s): /home/user/TIPTOE/850nm/350_nm_Drive_lower_Int//1/surface_Rn
#         end,turnOff: inft, ABRUPT (Caution)
#
#    axis Points      Emin  Emax       spacing
#      --   ----   -------   ---   -----------
#     kRn     64 7.178e-05 0.294 k-equidistant
#
#            Surfaces: default (at complex scaling radius)
#
#
#  ===  OPERATORS  ===============================================================
#
#         Hamiltonian: 1/2<<Laplacian>>-<1><1><trunc[5,15]/Q>
#           Region Rn: only spectral amplitudes
#         Interaction: iLaserAz[t]<<D/DZ>>+iLaserAx[t]<<D/DX>>+iLaserAy[t]<<D/DY>>
#           Region Rn:
#          HamInitial: H(t=Begin)
#
#  Expectation Values: Occupation[0,1,2,3,4,5]
#          Projection: default
#  --- potentials truncated by trunc[0,15] ---
#
#
#
#  ===  Laser  ===================================================================
#
#    polAxis Shape Intens(W/cm2) lambda(nm) photon(eV)  FWHM  begin    end phiCEO
#      -----   ---   -----------   --------   --------   ---   ----   ----   ----
#    [1 0 0]  cos8       7.5e+13        850      1.459 117.2   -315    315
#    [1 0 0]  cos8         6e+09        350      3.542 38.45 -547.3 -340.7  1.571
#
#  ponderomotive potential (eV): 5.06
#
#       Initial state: atBegin for operator H(t=Begin)
#
#
#  ===  OUTPUT  ==================================================================
#           Directory: /home/user/TIPTOE/850nm/350_nm_Drive_lower_Int//1/S_Rn/
#
#
#
#
#  ===  End of Input - timing  ===================================================
#
#                      File: Name                          calls   cpu(total)   cpu/call [samp]
#                 run_trecx: all                              10        39.2        3.92
#                mpiWrapper: MPI                          894613          18    2.01e-05
#              initialState: create                            1        9.25        9.25
#                 run_trecx: setup                             6        3.89       0.649
#                 run_trecx: buildOperators                    1       0.267       0.267
#                     tRecX: expecOps                          1        0.11        0.11
#            spectrumISurff: iSurff                            1    0.000137    0.000137
#                 run_trecx: timePropagate                     1    2.36e-07    2.36e-07
# timer overhead/call (sec): 6.09e-08
# timer overhead/call (sec): 1.19e-09 (sample=1024)
#  *** Only integration of source - no Propagation operator defined ***
#
#  !!! --- CURRENT WARNINGS (see /home/user/TIPTOE/850nm/350_nm_Drive_lower_Int//1/WARNINGS) --- !!!
#                   0: trunc[5,15]/Q  has non-analytic point in quadrature interval [ 0 , 15 ]
#                  28: Absorption:upper OBSOLESCENT -- change name to "radius"
#                  56: Axis:lower end OBSOLESCENT -- change name to "lowerEnd"
#                  70: Axis:upper end OBSOLESCENT -- change name to "upperEnd"
#                   0: trunc[5,15]/Q  has non-analytic point in quadrature interval [ 0 , 15 ]
#  *** initial state: ZERO ***
#
#
#  ===  Start Propagation - timing  ==============================================
#
#                      File: Name                          calls   cpu(total)   cpu/call [samp]
#                 run_trecx: all                              13        39.5        3.04
#                mpiWrapper: MPI                          894620          18    2.01e-05
#              initialState: create                            2        9.25        4.63
#                 run_trecx: setup                             6           4       0.666
#                 run_trecx: buildOperators                    2       0.269       0.135
#                     tRecX: expecOps                          1        0.11        0.11
#            spectrumISurff: iSurff                            1    0.000137    0.000137
#                 run_trecx: timePropagate                     1    2.36e-07    2.36e-07
# timer overhead/call (sec): 6.84e-08
# timer overhead/call (sec): 1.18e-09 (sample=1024)
#
#
#  ===  PROPAGATION PARAMETERS  ==================================================
#
#     begin end print   store fixStep   accuracy cutEnergy method
#      ----   --   ---   -----   -----   --------   -------   ----
#    -547.3 315 43.12 0.04174 0.04174 no control        50  euler
#
#
#
#  ===  TIME PROPAGATION (/home/user/TIPTOE/850nm/350_nm_Drive_lower_Int//1/S_Rn/)
#
#           <Overlap>: <1><1><GridWeight> at hierarchy Phi.Eta.specRn.kRn
#
#   Initial <Overlap>: 0
#
#       CPU   (%)     Time <Ovr(Phi.Eta.s...> <Overlap>
#      -----   --   ------   ----------------   -------
#          0    0 -547.331                  0         0
#      2.631    5 -504.211 2.8022174638153e-07 4.8022010221848e-11
#      4.796   10 -461.091 4.7643871295931e-08 3.9382337309838e-11
#        6.8   15 -417.971 2.2134005543696e-07 4.6567447700792e-11
#      8.954   20 -374.851 1.1976012801315e-07 3.4834171469404e-11
#      11.54   25 -331.731 1.3394596195344e-07 4.3965088476841e-11
#      13.62   30 -288.611 2.0145169402655e-07 3.8742441100748e-11
#      15.79   35 -245.491 6.6808875086863e-08 4.1878129519629e-11
#      18.01   40 -202.371 2.4860280538587e-07 4.0990185883647e-11
#       20.7   45 -159.251  1.130289626752e-07 7.8085428908055e-11
#      24.72   50 -116.131 3.9451688923608e-07 1.0316932274286e-10
#      27.15   55 -73.0109 2.3526658475444e-06 1.9574646756344e-09
#      29.78   60 -29.8909   0.025929060611005  1.310839856232e-05
#      32.34   65  13.2291    0.17678388149094 0.00015574831754251
#      34.83   70  56.3491    0.88542064676142   0.000575912952435
#      37.72   75  99.4691    0.88902996844822 0.00088909625998966
#      41.13   80  142.589    0.89370334584842 0.00096746386934954
#      43.94   85  185.709    0.84954748141205 0.00097995948194211
#      46.72   90  228.829    0.83094642491612 0.00098694002645658
#      50.28   95  271.949    0.82306004278513 0.00098886691607505
#      53.58  100  315.025    0.81311852975912 0.00098856301765581
#  *** adding iSurff correction ***
#  *** Photo-electron amplitudes on /home/user/TIPTOE/850nm/350_nm_Drive_lower_Int//1/S_Rn/ampl ***
#
#  TimePropagator euler: calls=0, fixed step=0.041741740070742
#
#  !!! --- CURRENT WARNINGS (see /home/user/TIPTOE/850nm/350_nm_Drive_lower_Int//1/WARNINGS) --- !!!
#                   0: trunc[5,15]/Q  has non-analytic point in quadrature interval [ 0 , 15 ]
#                  28: Absorption:upper OBSOLESCENT -- change name to "radius"
#                  56: Axis:lower end OBSOLESCENT -- change name to "lowerEnd"
#                  70: Axis:upper end OBSOLESCENT -- change name to "upperEnd"
#                   0: trunc[5,15]/Q  has non-analytic point in quadrature interval [ 0 , 15 ]
#
#
#  ===  End Propagation - timing  ================================================
#
#                      File: Name                          calls   cpu(total)   cpu/call [samp]
#                 run_trecx: all                              13        93.4        7.18
#                mpiWrapper: MPI                         1059622        30.3    2.86e-05
#              initialState: create                            2        9.25        4.63
#                 run_trecx: setup                             6           4       0.666
#                 run_trecx: buildOperators                    2       0.269       0.135
#                     tRecX: expecOps                          1        0.11        0.11
#            spectrumISurff: iSurff                            1    0.000137    0.000137
#                 run_trecx: timePropagate                     2    3.67e-07    1.84e-07
# timer overhead/call (sec): 5.96e-08
# timer overhead/call (sec): 1.51e-09 (sample=1024)
#
#
#  *** further output on /home/user/TIPTOE/850nm/350_nm_Drive_lower_Int//1/outspec ***
#  ***  Integral of Spectrum: 0  [ Phi.Eta.specRn.kRn ] ***
#  ***    spectra file /home/user/TIPTOE/850nm/350_nm_Drive_lower_Int//1/S_Rn/spec_total ***
#  *** added amplitude file /home/user/TIPTOE/850nm/350_nm_Drive_lower_Int//1/S_Rn/ampl ***
#  ***    spectra file /home/user/TIPTOE/850nm/350_nm_Drive_lower_Int//1/spec_total ***
#
#
#  ===  Evaluation of Expectation Values in the Unbounded Region  ================
#
#                              Definition            <Op> Validity
#      ----------------------------------   -------------   ------
#                      <1><1><GridWeight> 0.0009901632772
#                    <1><Q><GridWeight*Q> 0.0002481237739
#     <cos(Q)><sqrt(1-Q*Q)><GridWeight*Q>               0
#     <sin(Q)><sqrt(1-Q*Q)><GridWeight*Q>               0
#
# ...
#                 run_trecx: all                               4       0.927       0.232
#                 run_trecx: setup                             3       0.263      0.0877
#                mpiWrapper: MPI                             513       0.029    5.66e-05
# timer overhead/call (sec): 8.6e-08
# timer overhead/call (sec): 1.22e-09 (sample=1024)
#  !!! WARNING --- trunc[5,15]/Q  has non-analytic point in quadrature interval [ 0 , 15 ] --- WARNING !!!
#  Exact numerical integration needs integrands that are analytic within every finite element.
#  Matrix elements will be discretization dependent and non-systematic errors may appear
#     - errors may be acceptably low, but convergence with order may be inconsistent
#     - for consistent convergence place element boundaries on non-analytic points
#
#
#  !!! WARNING --- trunc[5,15]/Q  has non-analytic point in quadrature interval [ 0 , 15 ] --- WARNING !!!
#
#                  !!! Limit=1 reached, no further warnings:  trunc[5,15]/Q  has ... !!!
#
#
# Parallel layout of Interaction+H0
# total load =75.761     (pre-receive)->[oper]->(post-send)    dataSize{#blocks}
# Process no 0,	loadDelta=  5%,	blocks= 34, ()->[0]->(1)	Send= 39{2}
# Process no 1,	loadDelta= -3%,	blocks= 30, ()->[1]->(0,2)	Send= 78{4}
# Process no 2,	loadDelta=  6%,	blocks= 36, ()->[2]->(1,3)	Send= 78{4}
# Process no 3,	loadDelta= -8%,	blocks= 28, ()->[3]->(2)	Send= 39{2}
#
# Parallel layout of mapFromFullToContracted
# total load =8.3329     (pre-receive)->[oper]->(post-send)    dataSize{#blocks}
# Process no 0,	loadDelta=-18%,	blocks= 12, ()->[0]->()
# Process no 1,	loadDelta=-18%,	blocks= 10, ()->[1]->(0)	Send= 16{5}
# Process no 2,	loadDelta= 16%,	blocks= 12, ()->[2]->(0)	Send= 25{6}
# Process no 3,	loadDelta= 20%,	blocks= 10, ()->[3]->(0)	Send= 25{5}
#
# Parallel layout of mapToFullFromContracted
# total load =9.3796999999999     (pre-receive)->[oper]->(post-send)    dataSize{#blocks}
# Process no 0,	loadDelta=-13%,	blocks= 12, ()->[0]->()
# Process no 1,	loadDelta=-11%,	blocks= 10, (0)->[1]->()	Recv= 16{5}
# Process no 2,	loadDelta= 16%,	blocks= 12, (0)->[2]->()	Recv= 25{6}
# Process no 3,	loadDelta=  8%,	blocks= 10, (0)->[3]->()	Recv= 25{5}
#
#  *** non-constant parameters in operator "Interaction+H0": iLaserAz[t], iLaserAx[t], iLaserAy[t] ***
#
#  !!! --- CURRENT WARNINGS (see /home/user/TIPTOE/850nm/350_nm_Drive_lower_Int//6/WARNINGS) --- !!!
#                   0: trunc[5,15]/Q  has non-analytic point in quadrature interval [ 0 , 15 ]
#                  12: Absorption:upper OBSOLESCENT -- change name to "radius"
#                  24: Axis:lower end OBSOLESCENT -- change name to "lowerEnd"
#                  30: Axis:upper end OBSOLESCENT -- change name to "upperEnd"
#  *** Initial state calculation ***
#  *** initial state: eigenvector 1 of time-evolution at t=-358.320885138 ***
#
#
#  ===  Start Propagation - timing  ==============================================
#
#                      File: Name                          calls   cpu(total)   cpu/call [samp]
#                 run_trecx: all                               7        11.3        1.62
#              initialState: create                            1        9.07        9.07
#                mpiWrapper: MPI                            9848        4.71    0.000478
#                 run_trecx: setup                             3        1.38        0.46
#                 run_trecx: buildOperators                    1       0.473       0.473
#                     tRecX: expecOps                          1       0.102       0.102
# timer overhead/call (sec): 5.41e-08
# timer overhead/call (sec): 1.11e-09 (sample=1024)
#
#
#  ===  PROPAGATION PARAMETERS  ==================================================
#
#     begin end print   store fixStep   accuracy cutEnergy method
#      ----   --   ---   -----   -----   --------   -------   ----
#    -358.3 315 33.67 0.04174    0.04 no control        50    RK4
#
#  ***  Expectation values will only be computed at TimePropagation:print times ***
#
#
#  ===  TIME PROPAGATION (/home/user/TIPTOE/850nm/350_nm_Drive_lower_Int//6/)  ===
#
#         <Occ{H0:0}>: |0><0| of hamiltonian at hierarchy Phi.Eta.Rn.Rn
#         <Occ{H0:1}>: |1><1| of hamiltonian at hierarchy Phi.Eta.Rn.Rn
#         <Occ{H0:2}>: |2><2| of hamiltonian at hierarchy Phi.Eta.Rn.Rn
#         <Occ{H0:3}>: |3><3| of hamiltonian at hierarchy Phi.Eta.Rn.Rn
#         <Occ{H0:4}>: |4><4| of hamiltonian at hierarchy Phi.Eta.Rn.Rn
#         <Occ{H0:5}>: |5><5| of hamiltonian at hierarchy Phi.Eta.Rn.Rn
#
#        Initial <H0>: -0.49999176498036
#
#       CPU   (%)     Time <Ovr(Phi.Eta.R...>              <H0> <Occ{H0:0}>         <Occ{H0:1}>         <Occ{H0:2}>         <Occ{H0:3}>         <Occ{H0:4}>         <Occ{H0:5}>
#      -----   --   ------   ----------------   ---------------   ---------   -----------------   -----------------   -----------------   -----------------   -----------------
#          0    0 -358.321                  1 -0.49999176498036           1 9.6171501027783e-21 -8.386818847065e-18 6.6167214611033e-21 4.6850547495958e-22 1.5440204937006e-17
#      1.332    5 -324.651    0.9999999992524 -0.49999176455833 0.99999999915696 5.7361384882509e-11 -6.2624795451598e-18 4.8850535704679e-21 1.1903396884123e-11 -1.2570335783903e-17
#       2.46   10 -290.981   0.99999999850479 -0.49999172626877  0.9999999070484 7.5012628293423e-08  2.2650039038803e-14 1.2452336087974e-14 7.7765139717061e-09  1.6442926958359e-14
#      3.345   15 -257.311   0.99999999775708 -0.49998630953245 0.99998867791976  7.510353595902e-06  8.2108642242405e-11 4.0786750556243e-11 1.2623079075952e-06  1.5457736270463e-12
#       3.95   20 -223.641   0.99999999700935 -0.49999154908605 0.99999948279126  4.178904108519e-07   2.100279145429e-11 3.5703893257461e-13 4.5003515345523e-08  2.2603397145403e-13
#       5.83   25 -189.971    0.9999999962618 -0.49995784753882 0.99993147859499 4.3276099206272e-05  1.4977121523139e-09 8.9211437779797e-10 8.0367886384049e-06  1.1707950355193e-10
#      6.715   30 -156.301   0.99999999550956 -0.49877487183441 0.99756383299758  0.0015115738282746  1.6214465555044e-06 9.9936895401324e-07 0.00028876309299103  1.5864469254496e-07
#      7.394   35 -122.631   0.99999999472389 -0.49847051840589 0.99685549929749  0.0020591566364654    4.48841689817e-06 2.5642509567068e-06 0.00035531680433015  2.7767733921721e-07
#       7.97   40 -88.9609   0.99999999357953 -0.42529544558806 0.86300956422813   0.064234313642372   0.0045675537089339  0.0022250699455745   0.016090912168375  0.00057624733054667
#       8.52   45 -55.2909   0.99999993785608 -0.49085606808906  0.9804409178001   0.013550747976839   0.0002368805800725  0.0001472902072893  0.0018334971802349  8.4678783249285e-06
#      9.095   50 -21.6209   0.99998162854455 -0.20565851357114 0.57639266185486   0.092570735920414    0.026035265303447  0.0073607234778359   0.036392124982575   0.0052787667064042
#      9.636   55  12.0491   0.99986786080053 -0.35855372025358   0.753116118148   0.089963189835403    0.014292377516447  0.0059423568959246   0.031072237409591   0.0020621098318663
#      10.25   60  45.7191   0.99940687753487 -0.39528430933824 0.81004881890383   0.083458613202745   0.0079579233507005  0.0042505078953088   0.021771334403398  0.00093285420841176
#      10.78 65.01  79.3891   0.99918617811318 -0.41476961415844  0.8452208007567   0.070402166934461    0.005756947794392  0.0023446774465108   0.018239597654412  0.00058956026259112
#       11.4 70.01  113.059   0.99908505576537 -0.49784673553271 0.99562434342781  0.0021243047795852  1.1592087674842e-05 7.5094898700627e-06  0.0003629293178199  1.0377938281988e-06
#      12.07 75.01  146.729    0.9990343583375 -0.49613901449635 0.99225955991959  0.0043154071823355  1.8072650068419e-05 3.3468217917411e-06  0.0006976233948451  2.0010928642606e-06
#      12.55 80.01  180.399   0.99902413112084 -0.49947076162003 0.99895334328348 1.9230558482382e-05  1.4180518490367e-05 1.8948657859808e-05 2.0517661041692e-06  1.3877022751181e-07
#      13.15 85.01  214.069   0.99901778235419 -0.49947906092072 0.99897060399364  2.367560979467e-06   1.408119264802e-05 1.9055314560736e-05 6.0246160997481e-06  1.9566637469064e-07
#       13.7 90.01  247.739   0.99901457101555 -0.49948213999699 0.99897648967591 1.7989288485263e-07  1.4100723854353e-05 1.8235636718048e-05 3.8420803890439e-06  2.2324983946199e-07
#       14.4 95.01  281.409   0.99901408613521 -0.49948213493732 0.99897646616766 1.5595030485684e-07  1.4089702627118e-05 1.8371069572807e-05 3.8444205174349e-06  2.2011587152008e-07
#      14.94   100  315.025   0.99901438464237 -0.49948214957631 0.99897646558967 1.5604731212478e-07  1.4094667365502e-05 1.8748500537656e-05 3.7773115278664e-06  2.1010378183326e-07
#
#
#  ===  Info  ====================================================================
#    Imaginary expectation values
#    Operator: value where maximal imaginary part appears
#    Occ{H0:1}: (0.0835,2.92e-06)
#    Occ{H0:2}: (0.0143,-2.94e-06)
#    Occ{H0:3}: (0.00594,-3.14e-05)
#    Occ{H0:4}: (0.0182,-3.43e-05)
#    Occ{H0:5}: (0.00206,4.27e-05)
#
#    Complex expectation values can appear with complex scaling.
#    Physical interpretation of expecation values is limited
#    to within the magnitude of the imaginary part
#  ================================================================
#
#  *** compute iSurff spectral decomposition for size=858 ***
#
#  TimePropagator RK4: calls=67356, fixed step=0.04
#
#  !!! --- CURRENT WARNINGS (see /home/user/TIPTOE/850nm/350_nm_Drive_lower_Int//6/WARNINGS) --- !!!
#                   0: trunc[5,15]/Q  has non-analytic point in quadrature interval [ 0 , 15 ]
#                  12: Absorption:upper OBSOLESCENT -- change name to "radius"
#                  24: Axis:lower end OBSOLESCENT -- change name to "lowerEnd"
#                  30: Axis:upper end OBSOLESCENT -- change name to "upperEnd"
#                   0: trunc[5,15]/Q  has non-analytic point in quadrature interval [ 0 , 15 ]
#
#
#  ===  End Propagation - timing  ================================================
#
#                      File: Name                          calls   cpu(total)   cpu/call [samp]
#                 run_trecx: all                               7        26.5        3.79
#                mpiWrapper: MPI                          700467        10.5    1.49e-05
#              initialState: create                            1        9.07        9.07
#                 run_trecx: setup                             3        1.38        0.46
#                 run_trecx: buildOperators                    1       0.473       0.473
#                     tRecX: expecOps                          1       0.102       0.102
#            spectrumISurff: iSurff                            1    0.000245    0.000245
#                 run_trecx: timePropagate                     1    2.68e-07    2.68e-07
# timer overhead/call (sec): 5.57e-08
# timer overhead/call (sec): 1.35e-09 (sample=1024)
#
#
#  *** further output on /home/user/TIPTOE/850nm/350_nm_Drive_lower_Int//6/S_Rn/outf ***
#  Master host = mpq6p100 (4 processes)
#
#
#
#  ===  DISCRETIZATION AND INCOMING FLUX  ========================================
#
#                Name: Phi.Eta.surfRn.ValDerRn
#         Coordinates: Phi.Eta.kRn
#
#           source(s): /home/user/TIPTOE/850nm/350_nm_Drive_lower_Int//6/surface_Rn
#         end,turnOff: inft, ABRUPT (Caution)
#
#    axis Points      Emin  Emax       spacing
#      --   ----   -------   ---   -----------
#     kRn     64 7.178e-05 0.294 k-equidistant
#
#            Surfaces: default (at complex scaling radius)
#
#
#  ===  OPERATORS  ===============================================================
#
#         Hamiltonian: 1/2<<Laplacian>>-<1><1><trunc[5,15]/Q>
#           Region Rn: only spectral amplitudes
#         Interaction: iLaserAz[t]<<D/DZ>>+iLaserAx[t]<<D/DX>>+iLaserAy[t]<<D/DY>>
#           Region Rn:
#          HamInitial: H(t=Begin)
#
#  Expectation Values: Occupation[0,1,2,3,4,5]
#          Projection: default
#  --- potentials truncated by trunc[0,15] ---
#
#
#
#  ===  Laser  ===================================================================
#
#    polAxis Shape Intens(W/cm2) lambda(nm) photon(eV)  FWHM  begin    end phiCEO
#      -----   ---   -----------   --------   --------   ---   ----   ----   ----
#    [1 0 0]  cos8       7.5e+13        850      1.459 117.2   -315    315
#    [1 0 0]  cos8         6e+09        350      3.542 38.45 -358.3 -151.7  1.571
#
#  ponderomotive potential (eV): 5.06
#
#       Initial state: atBegin for operator H(t=Begin)
#
#
#  ===  OUTPUT  ==================================================================
#           Directory: /home/user/TIPTOE/850nm/350_nm_Drive_lower_Int//6/S_Rn/
#
#
#
#
#  ===  End of Input - timing  ===================================================
#
#                      File: Name                          calls   cpu(total)   cpu/call [samp]
#                 run_trecx: all                              10        27.1        2.71
#                mpiWrapper: MPI                          701081        10.5     1.5e-05
#              initialState: create                            1        9.07        9.07
#                 run_trecx: setup                             6        1.98        0.33
#                 run_trecx: buildOperators                    1       0.473       0.473
#                     tRecX: expecOps                          1       0.102       0.102
#            spectrumISurff: iSurff                            1    0.000245    0.000245
#                 run_trecx: timePropagate                     1    2.68e-07    2.68e-07
# timer overhead/call (sec): 6.07e-08
# timer overhead/call (sec): 2.4e-09 (sample=1024)
#  *** Only integration of source - no Propagation operator defined ***
#
#  !!! --- CURRENT WARNINGS (see /home/user/TIPTOE/850nm/350_nm_Drive_lower_Int//6/WARNINGS) --- !!!
#                   0: trunc[5,15]/Q  has non-analytic point in quadrature interval [ 0 , 15 ]
#                  28: Absorption:upper OBSOLESCENT -- change name to "radius"
#                  56: Axis:lower end OBSOLESCENT -- change name to "lowerEnd"
#                  70: Axis:upper end OBSOLESCENT -- change name to "upperEnd"
#                   0: trunc[5,15]/Q  has non-analytic point in quadrature interval [ 0 , 15 ]
#  *** initial state: ZERO ***
#
#
#  ===  Start Propagation - timing  ==============================================
#
#                      File: Name                          calls   cpu(total)   cpu/call [samp]
#                 run_trecx: all                              13        27.4        2.11
#                mpiWrapper: MPI                          701088        10.5     1.5e-05
#              initialState: create                            2        9.07        4.53
#                 run_trecx: setup                             6        2.08       0.347
#                 run_trecx: buildOperators                    2       0.475       0.237
#                     tRecX: expecOps                          1       0.102       0.102
#            spectrumISurff: iSurff                            1    0.000245    0.000245
#                 run_trecx: timePropagate                     1    2.68e-07    2.68e-07
# timer overhead/call (sec): 5.72e-08
# timer overhead/call (sec): 1.13e-09 (sample=1024)
#
#
#  ===  PROPAGATION PARAMETERS  ==================================================
#
#     begin end print   store fixStep   accuracy cutEnergy method
#      ----   --   ---   -----   -----   --------   -------   ----
#    -358.3 315 33.67 0.04174 0.04174 no control        50  euler
#
#
#
#  ===  TIME PROPAGATION (/home/user/TIPTOE/850nm/350_nm_Drive_lower_Int//6/S_Rn/)
#
#           <Overlap>: <1><1><GridWeight> at hierarchy Phi.Eta.specRn.kRn
#
#   Initial <Overlap>: 0
#
#       CPU   (%)     Time <Ovr(Phi.Eta.s...> <Overlap>
#      -----   --   ------   ----------------   -------
#          0    0 -358.321                  0         0
#       2.43    5 -324.651 1.9297575792178e-07 3.4589697057617e-11
#      4.289   10 -290.981 2.4901433367407e-07 4.4809994312439e-11
#      6.568   15 -257.311 3.1359710958233e-08 3.5187947455886e-11
#      8.209   20 -223.641 1.4084156447912e-07 3.8476509551151e-11

# %%
import os
os.path.join(os.environ['HOME'],'tRecX','tRecX')
# Out:
# '/home/user/tRecX/tRecX'

# %%
# !pip install --upgrade SciPy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: SciPy in /usr/lib/python3/dist-packages (1.8.0)
# Collecting SciPy
#   Downloading scipy-1.13.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 39.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy<2.3,>=1.22.4 in /home/user/.local/lib/python3.10/site-packages (from SciPy) (1.26.4)
# Installing collected packages: SciPy
# Successfully installed SciPy-1.13.0
